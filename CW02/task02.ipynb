# %%
class Solution:
    def minSubArrayLen(self, target: int, nums: list[int]) -> int:
        l = 0
        r = 1
        while r<len(nums):
            sum += nums[r]
            if sum >= target:
